# %%
import pandas as pd

# %%
df = pd.read_csv("Organizations.csv")
df.head()
# Out:
#    id                                               name    country  \
# 0   1                                       BILLA s.r.o.  Slovensko
# 1   2                Kaufland Slovenská republika v.o.s.  Slovensko
# 2   3                   Lidl Slovenská republika, s.r.o.  Slovensko
# 3   4                                     SLOVNAFT, a.s.  Slovensko
# 4   5  Štatistické a evidenčné vydavateľstvo tlačív,a...  Slovensko
#
#           ico        ic_dph           dic  \
# 0  31347037.0  SK2020312503  2.020313e+09
# 1  35790164.0  SK2020234216  2.020234e+09
# 2  35793783.0  SK2020279415  2.020279e+09
# 3  31322832.0  SK2020372640  2.020373e+09
# 4  31331131.0  SK2020295860  2.020296e+09
#
#                            municipality  postal_code  \
# 0     Bratislava - mestská časť Ružinov      82102.0
# 1  Bratislava - mestská časť Nové Mesto      83104.0
# 2     Bratislava - mestská časť Ružinov      82102.0
# 3     Bratislava - mestská časť Ružinov      82412.0
# ...

# %%
df["municipality"].value_counts()
# Out:
# municipality
# Bratislava - mestská časť Ružinov        39
# Bratislava - mestská časť Staré Mesto    38
# Bratislava - mestská časť Nové Mesto     22
# Bratislava - mestská časť Petržalka      17
# Bratislava - mestská časť Karlova Ves     8
#                                          ..
# Galanta                                   1
# Trstená                                   1
# Bernolákovo                               1
# Trnava                                    1
# Košice - mestská časť Sídlisko KVP        1
# Name: count, Length: 79, dtype: int64

# %%
print(df["name"].nunique())
print(df.shape)
# Out:
# 273
# (277, 20)

# %%
print(df["id"].nunique())
print(df.shape)
# Out:
# 42
# (42, 2)

# %%
df = pd.read_csv("ProductCategories.csv")
df
# Out:
#           id                       category  product_id
# 0          1           drinks/non-alcoholic           1
# 1          2               home/maintenence           1
# 2          3           drinks/mineral-water           1
# 3          4           drinks/non-alcoholic           2
# 4          5                 dairy/joghurts           2
# ...      ...                            ...         ...
# 26377  26378     basic/jams-marmelade-honey        6750
# 26378  26379  basic/canned-fruits-vegetable        6750
# 26379  26380               home/maintenence        6751
# 26380  26381                    home/office        6751
# 26381  26382                  home/cleaning        6751
#
# [26382 rows x 3 columns]

# %%
df = pd.read_csv("ProductItems.csv")
df.head()
# Out:
#    id  quantity  product_id  fs_receipt_id  created_date  last_modified_date  \
# 0   1       1.0           1              1           NaN                 NaN
# 1   2       6.0           2              1           NaN                 NaN
# 2   3       1.0           3              1           NaN                 NaN
# 3   4       1.0           4              1           NaN                 NaN
# 4   5       1.0           5              1           NaN                 NaN
#
#    created_by  last_modified_by  discount_id
# 0         NaN               NaN          NaN
# 1         NaN               NaN          NaN
# 2         NaN               NaN          NaN
# 3         NaN               NaN          NaN
# 4         NaN               NaN          NaN

# %%
df = pd.read_csv("Receipts.csv")
df.head()
# Out:
#    id                          receipt_id       ico  cash_register_code  \
# 0   1  O-3767E66C4F9D4D9DA7E66C4F9DFD9D0E  31347037   88820203125030016
# 1   2  O-9F29E0078F3F4F2CA9E0078F3F0F2C94  35790164   88820202342160712
# 2   3  O-C75BD43CDF704A779BD43CDF70EA7762  31347037   88820203125030016
# 3   4  O-13DF179BEA9443D89F179BEA9453D8A8  31347037   88820203125030016
# 4   5  O-2CBA56EADDB34873BA56EADDB3787329  35793783   88820202794151418
#
#             issue_date          create_date  customer_id         dic  \
# 0  02.04.2022 15:09:57  02.04.2022 15:09:57          NaN  2020312503
# 1  05.03.2022 13:56:16  05.03.2022 13:56:16          NaN  2020234216
# 2  05.03.2022 14:36:15  05.03.2022 14:36:15          NaN  2020312503
# 3  26.02.2022 14:44:56  26.02.2022 14:44:56          NaN  2020312503
# 4  29.09.2023 11:32:10  29.09.2023 11:32:10          NaN  2020279415
#
#          ic_dph invoice_number  ... unit_name unit_type  \
# 0  SK2020312503            NaN  ...       NaN  STANDARD
# ...

# %%
df["created_by"].value_counts()
# Out:
# created_by
# 7     758
# 5      74
# 36     27
# 19     23
# 1      18
# 13     12
# 18     11
# 21      9
# 16      8
# 12      8
# 3       7
# 11      3
# 2       2
# 38      2
# 40      2
# 37      1
# 42      1
# Name: count, dtype: int64

# %%
df = pd.read_csv("Products.csv")
df.head()
# Out:
#    id                  name item_type  price  vat_rate               category  \
# 0   1  NESTEA CITRÓN 1,5l           K   0.99      20.0   drinks/non-alcoholic
# 1   2  ZÁLOHA PET                   K   0.15       0.0   drinks/non-alcoholic
# 2   3  MAG.GREP 1,5l                K   0.65      20.0   drinks/non-alcoholic
# 3   4  MAG.PER.1,5l                 K   0.59      20.0   drinks/mineral-water
# 4   5  Raciol rastl.1l              K   2.59      20.0  basic/oil-acid-grease
#
#    organization_id  org_unit_id         created_date   last_modified_date  \
# 0                1            1  2023-09-28 22:57:45  2023-09-28 22:57:46
# 1                1            1  2023-09-28 22:57:45  2023-11-22 12:15:34
# 2                1            1  2023-09-28 22:57:45  2023-09-28 22:57:46
# 3                1            1  2023-09-28 22:57:45  2023-09-28 22:57:46
# 4                1            1  2023-09-28 22:57:45  2023-09-28 22:57:46
#
#    created_by last_modified_by is_overridden
# ...

# %%
df["name"] = df["name"].str.strip()

# %%
df.iloc[2, 1]
# Out:
# 'MAG.GREP 1,5l'

# %%
df[df["name"] == "health/lady"]

# %%
df["name"].value_counts()
# Out:
# name
# Zľava Lidl Plus                             236
# Banány                                       47
#  ZĽAVA PRE ČLENA                             30
# Kaufland Card                                28
# Bio banány                                   22
#                                            ...
# SF MÄSOVÝ PRÍP.MIX                            1
# PEPSI 2,25l                                   1
# JAZMÍN.RYŽA 500g                              1
# Cibuľa červ.500g                              1
# xkko froté obrúsky biele 6k                   1
# Name: count, Length: 4453, dtype: int64

# %%
df["name"].value_counts().to_dict()
# Out:
# {'Zľava Lidl Plus': 236,
#  'Banány': 47,
#  'ZĽAVA PRE ČLENA': 30,
#  'Kaufland Card': 28,
#  'Bio banány': 22,
#  'Banány voľné': 22,
#  'Farm.horné stehná': 20,
#  'Uhorky šalátové': 19,
#  'Zľava s kupónom': 19,
#  'Paprika červená': 18,
#  'Paradajky strapco.': 18,
#  'Paprika žltá': 17,
#  'Oravská slanina': 15,
#  'Maslo, 250g': 15,
#  'Cuketa': 15,
#  'Mrkva voľná': 14,
#  'EVO Diesel': 14,
#  'Biele hrozno 500g': 14,
#  'Natural Ultra 95 + ST(4)': 13,
#  '': 13,
#  'Brokolica 500g': 13,
#  'Mandarínky': 12,
#  'Smotan. nát. prír.': 12,
#  'Kečup jemný': 12,
#  'Zemiaky nesk.2kgB': 11,
#  'ZĽAVA PRE ČLENA        0.01': 11,
#  'Bio šalát.uhorky': 11,
#  'Zemiaky': 11,
#  'Jablká Evelina': 11,
#  'Biely jogurt 3,7%': 11,
#  'Bio cuketa 500g': 11,
#  'Mozzarella Classic': 10,
#  'Červené jablká': 10,
#  'Dusená šunka Pure': 10,
#  'ZĽAVA AKCIA': 10,
#  'Ov.kapsička-banán': 10,
#  'Maslo': 10,
#  'Jablká Golden Del.': 10,
#  'Kozmetické vreck.': 10,
#  'Žlava': 9,
# ...

# %%
df["created_by"].value_counts()
# Out:
# created_by
# 7     4621
# 5      989
# 3      278
# 1      250
# 36     182
# 19      91
# 16      80
# 2       76
# 38      42
# 12      41
# 18      35
# 21      34
# 13      19
# 11       5
# 42       2
# 37       1
# 40       1
# Name: count, dtype: int64

# %%
df = pd.read_csv("Users.csv")
df.head()
