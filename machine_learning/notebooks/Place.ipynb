# %%
import pandas as pd

# %%
products_df = pd.read_csv("Products.csv")
products_df
# Out:
#         id                                      name item_type  price  \
# 0        1                      NESTEA CITRÓN 1,5l           K   0.99
# 1        2                      ZÁLOHA PET                   K   0.15
# 2        3                      MAG.GREP 1,5l                K   0.65
# 3        4                      MAG.PER.1,5l                 K   0.59
# 4        5                      Raciol rastl.1l              K   2.59
# ...    ...                                       ...       ...    ...
# 6742  6747  Sanytol uni.sprej 500ml                          K   3.65
# 6743  6748  S&S KU 2x140 útrž.                               K   1.25
# 6744  6749  Dettol antibak.obrús 80ks                        K   6.65
# 6745  6750  babylove vlh.ut. 99%vody,80                      K   1.75
# 6746  6751  xkko froté obrúsky biele 6k                      K   6.95
#
#       vat_rate                   category  organization_id  org_unit_id  \
# ...
